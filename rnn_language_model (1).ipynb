# %%
[![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/pantelis-nlp/tutorial-nlp-notebooks/blob/main/rnn_language_model.ipynb)

# %%
data = 'Chios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and arid, with a ridge of mountains running the length of the island. The two largest of these mountains, Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3,898 ft)), are situated in the north of the island. The center of the island is divided between east and west by a range of smaller peaks, known as Provatas.'

# %%
# see here for notation http://cs231n.stanford.edu/slides/2018/cs231n_2018_lecture10.pdf
"""
Minimal character-level Vanilla RNN model. Written by Andrej Karpathy (@karpathy)
BSD License
"""
import numpy as np

# data I/O
#data = open('input.txt', 'r').read() # should be simple plain text file - you can use any (small) file in txt format from the web or type your own. 

chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print('data has %d characters, %d unique.' % (data_size, vocab_size))
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }

# hyperparameters
hidden_size = 100 # size of hidden layer of neurons
seq_length = 25 # number of steps to unroll the RNN for
learning_rate = 1e-1

# model parameters
Wxh = np.random.randn(hidden_size, vocab_size)*0.01 # input to hidden
Whh = np.random.randn(hidden_size, hidden_size)*0.01 # hidden to hidden
Why = np.random.randn(vocab_size, hidden_size)*0.01 # hidden to output
bh = np.zeros((hidden_size, 1)) # hidden bias
by = np.zeros((vocab_size, 1)) # output bias
# Out:
# data has 508 characters, 43 unique.

# %%
def sample(h, seed_ix, n):
  """ 
  sample a sequence of integers from the model 
  h is memory state, seed_ix is seed letter for first time step
  """
  x = np.zeros((vocab_size, 1))
  x[seed_ix] = 1
  ixes = []
  for t in range(n):
    h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
    y = np.dot(Why, h) + by
    p = np.exp(y) / np.sum(np.exp(y))
    ix = np.random.choice(range(vocab_size), p=p.ravel())
    x = np.zeros((vocab_size, 1))
    x[ix] = 1
    ixes.append(ix)
  return ixes

# %%
def lossFun(inputs, targets, hprev):
  """
  inputs,targets are both list of integers.
  hprev is Hx1 array of initial hidden state
  returns the loss, gradients on model parameters, and last hidden state
  """

  xs, hs, ys, ps = {}, {}, {}, {}
  hs[-1] = np.copy(hprev)
  loss = 0
  # forward pass
  for t in range(len(inputs)):
    xs[t] = np.zeros((vocab_size,1)) # encode in 1-of-k representation
    xs[t][inputs[t]] = 1
    hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
    ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
    ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
    loss += -np.log(ps[t][targets[t],0]) # softmax (cross-entropy loss)
  # backward pass: compute gradients going backwards
  dWxh, dWhh, dWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
  dbh, dby = np.zeros_like(bh), np.zeros_like(by)
  dhnext = np.zeros_like(hs[0])
  for t in reversed(range(len(inputs))):
    dy = np.copy(ps[t])
    dy[targets[t]] -= 1 # backprop into y. see http://cs231n.github.io/neural-networks-case-study/#grad if confused here
    dWhy += np.dot(dy, hs[t].T)
    dby += dy
    dh = np.dot(Why.T, dy) + dhnext # backprop into h
    dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity
    dbh += dhraw
    dWxh += np.dot(dhraw, xs[t].T)
    dWhh += np.dot(dhraw, hs[t-1].T)
    dhnext = np.dot(Whh.T, dhraw)
  for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
    np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
  return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-1]

# %%
n, p = 0, 0
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby = np.zeros_like(bh), np.zeros_like(by) # memory variables for Adagrad
smooth_loss = -np.log(1.0/vocab_size)*seq_length # loss at iteration 0

while True:
  # prepare inputs (we're sweeping from left to right in steps seq_length long)
  if p+seq_length+1 >= len(data) or n == 0: 
    hprev = np.zeros((hidden_size,1)) # reset RNN memory
    p = 0 # go from start of data
  inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
  targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]

  # sample from the model now and then
  if n % 1000 == 0:
    sample_ix = sample(hprev, inputs[0], 200)
    txt = ''.join(ix_to_char[ix] for ix in sample_ix)
    print('----\n %s \n----' % (txt, ))

  # forward seq_length characters through the net and fetch gradient
  loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
  smooth_loss = smooth_loss * 0.999 + loss * 0.001
  if n % 1000 == 0: print('iter %d, loss: %f' % (n, smooth_loss)) # print progress
  
  # perform parameter update with Adagrad
  for param, dparam, mem in zip([Wxh, Whh, Why, bh, by], 
                                [dWxh, dWhh, dWhy, dbh, dby], 
                                [mWxh, mWhh, mWhy, mbh, mby]):
    mem += dparam * dparam
    param += -learning_rate * dparam / np.sqrt(mem + 1e-8) # adagrad update

  p += seq_length # move data pointer
  n += 1 # iteration counter
# Out:
# ----
#  hios island in, wid, km (31 mi) at its widt by a range of th ism, mi) at its widest, covelrod inof ft)) and Epos (1,188 m (3,898 ft)), are sit4, (325.210 sq mi).[2] The terraint long from north to sou
# ----
# iter 0, loss: 93.936312
# ----
#  hios km th,4esle kin ins m sangrers (21 ,289 m of the islandes knrpeng kid ar th and of 52 ealis rid ofg of lanidy a ste of Prpit aangsoullanid beto m of sqm The and The lee twbe) ikinntewear, ,erid a
# ----
# iter 1000, loss: 65.692706
# ----
#  hios as benpnteesta The is istwealle lcentes it and m (18 m pe widerou m (1,188 mrEtenn descd, 83, Thed wean n kpe covid. m8 mi)) sheo m (3,8 m, 8methe rof the ecnndy are pond (3180 mountaing shof as
# ----
# iter 2000, loss: 42.563686
# ----
#  hios pond between lans (1,297 m The lenth nown as Prmi), f isea t ires ovid Epor) swidwea las Pounth anst in as bete (1,29 (325 Th and isthe sEpor (1,The ofg8 ridon) ann twin of st innn an aro m heong
# ----
# iter 3000, loss: 29.560728
# ----
#  hios, bunong aristh ang the lens, (1,898 ft) ounge mountarer,  ounthe islas Pr(3,555 kmet,o4,t50 (3289 my lwnes and is crea ler of km Pelistar.2 (325 The an ais, 5 The rof th, by a rang and peasth aor
# ----
# iter 4000, loss: 21.569832
# ----
#  hios in ange h,t andge of kf298 the isth of t4o3, 2] (1,t) ous ari) dintest by a rangesitho the island,  ft))) ouslandth of 89 ftuor (3 The as, Pesth ane lang, Pe kinge oit kies smat is wnoun tsof the
# ----
# iter 5000, loss: 16.272499
# ----
#  hios island belente center of the island isllenstait of the islanid,e, conge mountuits wid sasthe4,is ristarth, and bendest mateoun dir rof the istho th of i), Petgby kruor rwe mor ceerg are mallertau
# ----
# iter 6000, loss: 12.916722
# ----
#  hios islanor ang, Petor mountaincen of 842.289 mi).[2] The twi kidney th acenteroun island,  ft) kt or rounges ktaisth, out nong widests arnorth of thes,ind. bunesthe staislander area isl,est, of the
# ----
# iter 7000, loss: 10.326273
# ----
#  hios is peanis arest and wer porth of the om kmasth (31 smi).[22 (1,1,188 m sq mi).[2] The nord the rais, Peto mlcekth, smaoutsand. The nwid e of the lenslarge island. The twerin t anes mo) m2 ftho me
# ----
# iter 8000, loss: 8.549371
# ----
#  hios island Epos (188 mcetd pe widest, coveesisland id,  fnounthe center orf kd289 km (4e),g (1,188 mrth of land is dn)) ounge king an, langa divid,. (31 mind id E.id a ririn ase of smanth noun lenges
# ----
# iter 9000, loss: 7.375580
# ----
#  hios (3289 makis island in the north of the island. The twid, 29 (325 th, bet), island. Thean estios kseand id, 5 m (3,255 kthe island. The tgeang argnweeng area the island is divided 29 km2 km (3,25.
# ----
# iter 10000, loss: 6.453810
# ----
#  hios istarthe ista nata lengta ndenterin araa runn ase of sm of smalisland ar[ oun) long frof the island,  ft)), ar9 kmets of thesth, at itwid weest and e of smathe millength of the island. The ce) at
# ----
# iter 11000, loss: 5.454809
# ----
#  hios island is aren est by a range of smalleorureont of th, oun of 8h 50 km (31 mi) long areat its ridge of mofs ardis kpeak) y rmof 84,297 m (m kpeand af 842.29842.289 km2 (325.210 sq ft)), aid wides
# ----
# iter 12000, loss: 4.858814
# ----
#  hios islakvean a raen eouslanis th, o4,s2]29est of kmo mansastof kin. The island, the island is dinrest of thes aivided betweanes ai) ange ft mounta wTer island a widest, coveast ateous at itslands mo
# ----
# iter 13000, loss: 4.712394
# ----
#  hios iscednd wTero m cort ans Prcond, with a ridge of mountains rom mountain sland arous andge of mountainous (1,, ft),, are situated inis kmealisland arous andest, coveasth ane lenwid saouth the leno
# ----
# iter 14000, loss: 4.354692
# ----
#  hios island is crescearg ced, 5) rTero s.[25 218 m t(1,81, ft)), aid werinin a rwean nount and ion (1,297 m (4,255 ft)) rom mountains running the lengland, th, is cresceknes peaks, mat its,est and wes
# ----
# iter 15000, loss: 3.558956
# ----
#  hios island belenn n ksean ared 29 km (4b289 fthe length of the island is peatuits widest, covist by a ranta slinle length of the island s ountiored, cr(31 mi) last weargest by a range of  ft) arvis i
# ----
# iter 16000, loss: 3.621224
# ----
#  hios islatgo4255 ft)) an nou weringe of Praislallengeslnte ponlaer of the island. The centeis mousthathe mounllepeange) island. The center of the in kseanis in an n sariror are santh of the islarde  i
# ----
# iter 17000, loss: 2.796693
# ----
#  aios isea is of the island a wTeous and be nteous peanth of the island. The screange frof the island is divid,e lon long from north to soutains Peanor kidney screand Epon. pines peakveacedn eaneas (1,
# ----
# iter 18000, loss: 2.771589
# ----
#  hios island is cresceens kid verroun  to, 5.21,255 ftkd 7 The centhes mountaing rountains ouof 8ust, cy mountainrain kin a win siounta wTwid, witoon crescent in the nord 29 km (18 m dive north of the
# ----
# iter 19000, loss: 2.376937
# ----
#  hios island is ith of the island. The lenwid verris d mi) largest of theseislatve).2 (1,188 mat8 ft, id Epos aistains oun or kirer of the island a sountainstwok kmetuof 842 ft)y smaller peak) th of th
# ----
# iter 20000, loss: 2.458999
# ----
#  hios is peakgeth, long from noinge mounthe nor covering an area of 842.250 km (31 mi) long from north tho Peanthe lengesteof 8ust mountains rutw,e south, am kan area of 84.2[29 km (18 mountains rmount
# ----
# iter 21000, loss: 2.025681
# ----
#  hios island is crescent or kidney shaped, 50 km (3gth anth of the island. The two, fth, long from nor m (3,898 ft)), fof 8r mrtains running the length of the island. The two, ft) knd. The length of th
# ----
# iter 22000, loss: 2.061937
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long (1,18r] The the nan a range mof kmeto9m kmi), ,21, mourarge of smaller peathinteanges,i) long from crthow aris ange mountoous flernd 8r isl
# ----
# iter 23000, loss: 1.765736
# ----
#  hios island is crescenngth of the island. The center of the island. The two largest of these mountains, Pelineos (1,188 mutsathe mountains, Pelo sounts, fThe two last area the of 842.289 km (18 mi) at
# ----
# iter 24000, loss: 2.013438
# ----
#  hios islanin as Prto sitha is divinne linne land ia of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and arid, 29 km (18 mi) atha (1,29 km2 (1,m88 thow km Prpist and vaen of 842.289 8r8r9
# ----
# iter 25000, loss: 1.641629
# ----
#  hios islanor kidney shapis kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18es peatha id between eastpean area th, island is divided bethe lest and werino lasnd benkan ar[ The terri
# ----
# iter 26000, loss: 2.006064
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long frpontains of 842.289 km2 (325.210 sq md muts winge nord Pelined in n aseallenteateonth of 29 km (328 ft)), are situated in the north of th
# ----
# iter 27000, loss: 1.615395
# ----
#  hios islant and peaning the length of the island. The swTeous and Epos (1,188 m (3,898 fnth ateateof ay smaller peaks, knwpeange mountains, Pelineon (1,297 m (4,255 ft)) length of thesy long fri) at i
# ----
# iter 28000, loss: 1.309839
# ----
#  hios islapest by a range of smaller peath th a ridge of mountain nous and arid. 50 km (31 mi) long from north tgeuof 842 ft)), areas fange non (1,188 m (3,898 ft)), area the lengtha the lengesto89 fth
# ----
# iter 29000, loss: 1.573138
# ----
#  hios id.29 km (18 mi) at its widest, covering aivist and west,oun an nouned peang shrof the length of the island. The center of the island. The two larer an naed in tha ponth a ridge of mountains romt
# ----
# iter 30000, loss: 1.267866
# ----
#  hios island is poruated in the north of the island. Pellen a riving the length of the island. T ince tuits widest, covering and Epos (y cond. Theast and e of smalled in  screans martain of 842.289 km2
# ----
# iter 31000, loss: 1.122275
# ----
#  hios island is crescent or kirerwe ourthe island a wid vTpeen east and waen y screange mallentains, mountains running the length of thes nor kroe the length of the island. The center of the island is
# ----
# iter 32000, loss: 1.324840
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from nort aren east and 9 fn)., (3289 km2.289 km2 (1,m88 tho428 ft)), are situated in thent cy tuof 842.289 km2 (3298 ft)), are sinort ats8
# ----
# iter 33000, loss: 1.096004
# ----
#  hios island is crescent or cres anins rof mounge sithed by and west by a range of sq misto the non a range of smaning the length of the island a sounes rof the island. The two largest of these mon kse
# ----
# iter 34000, loss: 1.463375
# ----
#  hios island is crescent or kseaned s ong from no the slanepeaks, matuated 29 km mountainous and arid, with a ridge of mountains running the length of the islande the length of the island. The center o
# ----
# iter 35000, loss: 1.119388
# ----
#  hios island id sidtwon ks[29 ft)), are situated in the north of the island. The center of the island is divided between easnde widest, coved1, 88 m2 kndge of mountains running the lerg fraisthe lenged
# ----
# iter 36000, loss: 0.954447
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) long fr289 kmeth naed iwistom mountain slaney of 842.289 km2 (325.210 sq mi).[2] The terrain is moun
# ----
# iter 37000, loss: 0.873808
# ----
#  hios island is kidney shaped, 50 km (3,898 ft)), are situated init coved north of the isange of smanis crescenth arest and west by a range of mo the thentest by a range of smaller in n ais crescoverin
# ----
# iter 38000, loss: 1.684280
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long frof laris lanes mountains running the length of the island. The center of the island is divided bd29 f89 km2 (325.210 sq km28 muner an n s
# ----
# iter 39000, loss: 1.131693
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long fnof thof ) terad vbentwith, and Epos (1,188 m (3,898 ft)), ar9i) aing aus long fr28 mountains running the length of the island. The ts wid
# ----
# iter 40000, loss: 0.901083
# ----
#  hios island is crescent ousthe reosg m om the island is divided between east and west by a range of smalleisland is divecengerid area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and
# ----
# iter 41000, loss: 0.800834
# ----
#  hios island id kmentest by a range of smaller peaks,21,h (1,18m, ft)ang h iunslanese mountaita n as mrtof the island is divided between east and west by a range of smaller peaks, known as Prt owid 10
# ----
# iter 42000, loss: 0.751560
# ----
#  hios island is crescent or kidney shaped, 50 kmesnort, cent in terwe cang ans mountainous and 29 km (18 mi) an n pon kseto stof the lengest by a range of smaller peaks, known as Prto south, and 29 km
# ----
# iter 43000, loss: 0.722656
# ----
#  hios island is cresceanning the length of the island is divid,e lenged, Panno d, km2),sharid, with a ridge of mountains runnine the lengd Epos (1,188 mlanis kidney shaped, 50 km (31 mi) long from nort
# ----
# iter 44000, loss: 0.703002
# ----
#  hios island is crescent or (1,29 km (18 mi) ats88 2] k(3i) kange mountaita nd Epos (1,188 m2 (1,s28th the island. The center of the island. The two largest of these ft)), arth anth of the island is di
# ----
# iter 45000, loss: 3.834069
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at it inin a rid Pes,gthest by a range of smaller peaks, kndndest of these mountains, Pelineon (1,29
# ----
# iter 46000, loss: 1.995979
# ----
#  hios island is pon ar9 kteous long from north to south, and 29 km (18 mi) at its wider of the island is de) long fratween east and west by a range of smaller peaks, kveang lon at its widest, covering
# ----
# iter 47000, loss: 1.210807
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is suorit and ior are
# ----
# iter 48000, loss: 0.892076
# ----
#  hios islatuate the none length of the island. The two largest of these mountains, Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3,898 ft)), are situated in the north of the island is divide, Peletw
# ----
# iter 49000, loss: 0.757687
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long frunnid norid ith, and Epos (1,188 m (3,898 ft)), are situated in the north of the island. The two largest of these mountains, Pelineon (1,
# ----
# iter 50000, loss: 0.702434
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain in ekse nor kidney sh
# ----
# iter 51000, loss: 1.703496
# ----
#  hios island is crescent or sinin a rid rountain of 842.289 km2 (3, ktd The of the island is divided between east and west by a range of smaller peaks, known as Prto south, and 29 km (18 mi) at its wid
# ----
# iter 52000, loss: 1.063156
# ----
#  hios island id lang hen east and west by a range of smaller peaks, known as Prto south, and 29 km binean  rionges aivit atpean area of 842.289 8r8r Prpean area of 8h 5.210 sq math th a ridge of mounta
# ----
# iter 53000, loss: 0.808056
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and ar
# ----
# iter 54000, loss: 0.713175
# ----
#  hios island is crescent oris of the island. The center of the island is divided between eon and be rrareas kidney shaped, 50 km (31 mi) long from north con thest or kseamlast and west by a range of mo
# ----
# iter 55000, loss: 0.680610
# ----
#  hios island in the nde) long from nort ounta werinin lanis ist atof mountains running the length of the island. The center of the island. The center of the island. The two largest of these mountains,
# ----
# iter 56000, loss: 1.296039
# ----
#  hios island in teateond 29 km (18 mi) tuos km Peanes ith a ridge of mountaind in the) and Epon ksq The non ais of the len divided belenor screaknd, with a ridge of mountaind is crescent or kidne north
# ----
# iter 57000, loss: 1.405639
# ----
#  hios island is crescent or kidney shapounsth widney sh a ridge of mountains running the length of the island is of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and arid, with noun atwi s
# ----
# iter 58000, loss: 1.114680
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq matha rThe two largest of these mountains
# ----
# iter 59000, loss: 0.856618
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountains running
# ----
# iter 60000, loss: 1.114255
# ----
#  hios island is crescent or kidney shaped, 50 km (3, 50 km (4,255 ft)) and Epos (1,188 m (3,898 ft)), frof the island. The two largest of these mo4t scovering an area of 842.289 km2 (325.210 sq mi).[2]
# ----
# iter 61000, loss: 1.538244
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, aivided in the north of the island. 8rintainor are situateon (1,297 m (4,255 ft)) and 29 km (18 mi) long from north to
# ----
# iter 62000, loss: 0.989968
# ----
#  hios island is ourtainor areas kirinous and ange mand belerltof slapoungest or kios Thin the north of the islander of the island. The center of the island. The celnest, cand 29 km (18 mi) at its or] f
# ----
# iter 63000, loss: 0.784323
# ----
#  hios island is crescent or kidney shakndney sherin kse oid islanor are s ont ard i) and Epos (1,188 m (3,898 ft)), are situated in the nor ares (18 mi) aslentea is and apest of thes mom laris peaknd i
# ----
# iter 64000, loss: 0.692813
# ----
#  hios island is crescent or kidney shaped, 50 km (3, mustse mountains, Pelinte largest of these mountains, Pelineon (1,297 m (4,255 ft)) an nseat its widest by a ror kidney shaped, 50 km (31 mi) long f
# ----
# iter 65000, loss: 0.648195
# ----
#  hios island id laned, witwid , cres and 29 km (18e s210429 km (18 mi) at ithe laned is nd Epo cond isaan wees sheritsh wiong ar97 8] knd 10 sq mi).[2] The terrain is mountaince ning the island. The tw
# ----
# iter 66000, loss: 0.626910
# ----
#  hios island is crescent or kidney shaped, 50 km (3,898 ft)), are situated is crese of the island is divided between east and west by a raividne length of the island. The center of the ngd Epos (1,188
# ----
# iter 67000, loss: 1.913481
# ----
#  hios island is crescent of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and arid nond 29 km (18 mi) a inge nort mounth, of these mounteato kmatgbetwof ar9 ktwest ousllength of the island
# ----
# iter 68000, loss: 1.108306
# ----
#  hios island is crescent or kidney shaped, 50 km (3,898 ft)), ar97 8rr[29 f89 km (ed21, ft)), ais (1,297 m (4,255 ft)) and Epos (1,188 m (3,89898 ft)), are situated in llentea isllent ate north of the
# ----
# iter 69000, loss: 0.909214
# ----
#  hios island is crescent or kidney shanor islanoust, Preard island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 kme), aisth of the island. The center of the island. The
# ----
# iter 70000, loss: 0.701991
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) lon long from north to south, and 29 km (18 mi) rarea of 894i) kseaslangest of these mountains, Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m
# ----
# iter 71000, loss: 0.617457
# ----
#  hios island is crescent or kidney shaped, between east and west by a range of smaller peaks, knrid a range of mounth a ridge of mountains running the leng (1,297 m (4,255 ft)) and Epos (1,188 m (3,898
# ----
# iter 72000, loss: 1.346882
# ----
#  hios island is crescent or kidney shaed between east wid1, fn8a (1,255 The north of the island. T re situateos (1,188 m (3,898 ft)), are situateon ar9 kthe island. The center of the island is of 842.2
# ----
# iter 73000, loss: 0.873719
# ----
#  hios island is crescent orit of 50 km mountains an n kselintest by a range argth of (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and arid, with
# ----
# iter 74000, loss: 0.674485
# ----
#  hios island is crthe sland is divided i) kange of snor ar] Thea d inin as Prcond ridest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and arid, with a ridge of mounta
# ----
# iter 75000, loss: 0.595177
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and ar
# ----
# iter 76000, loss: 0.564601
# ----
#  hios islaivided munteand. 528 mu) owlenter.[2]29 km (18 m nown as Prto, 50 kisth of the island. The centerin n nist or kidney shaped, 50 km (31 mi) long from the island. The two largest ofth of the is
# ----
# iter 77000, loss: 2.373284
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and ar
# ----
# iter 78000, loss: 1.378698
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325 the lengest of these mountains, smallent its wid
# ----
# iter 79000, loss: 0.848206
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and ar
# ----
# iter 80000, loss: 0.637463
# ----
#  hios island is crescent or kidney shaped, 50 kmast and west by a range of smaller peaks, )) bateang aun an pan areat fntan as Prto han ase argthe island is desland ais mof the island. The center of th
# ----
# iter 81000, loss: 0.556109
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long frod 8thi), artooustha divided 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous
# ----
# iter 82000, loss: 1.412899
# ----
#  hios island is crescent or kien eatgest or d verris ak) tof mountains running the lengtha d mom 50t5 ltgthe cond f 889 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The
# ----
# iter 83000, loss: 0.848297
# ----
#  hios island is crescent of a rid is divided between east and west by a range of smaller peaks, known as Prtios (1,188 m (3,898 ft)), are situated in the north of the island is divided between east and
# ----
# iter 84000, loss: 0.627559
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to the nonth of the island. The two largest of these mounteato tha range of smaller peaks, known as Prto haped, 50 km (31 mi) lo
# ----
# iter 85000, loss: 0.538726
# ----
#  hios island is crthe situated in the north of the island. The center of the island is de stowi),e, conge of smalleest Peais smathe north of the island is divided between east anes aivided in the north
# ----
# iter 86000, loss: 1.330309
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 841,898 ft)), are situated in the north of the island. The two la
# ----
# iter 87000, loss: 0.813479
# ----
#  hios kmenterin cedngeasnd errelength of the islann id 29 km (18 mi) al ntaisth of the island. The centhes mountainous and arid, with a ridge of mountains and Epos (1,188 m (3,898 ft)), are situated in
# ----
# iter 88000, loss: 0.678961
# ----
#  hios island is crescent or kidney shapeasth countainous and arid, with a ridge of mountains running the length of the island. The two largest of these mountains, Pelineon (1,297 m (4,255 ft)) and Epos
# ----
# iter 89000, loss: 0.544830
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south a ridge of mountains running the length of the island. The two largeslinn  raitest Peliner and Epos (1,2] The terrain i
# ----
# iter 90000, loss: 0.863510
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering and Epos (1,188 m (3,898 ft)), are pon ksentest by a range of smaller peaks,
# ----
# iter 91000, loss: 0.616858
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, coverroid. The two largest of these mounta[thaed beteaid in the north of the islande
# ----
# iter 92000, loss: 0.599893
# ----
#  hios island is crescekngth of the island. The center of the island. The two largest of these mountains, Pelineon (1,297 m (4,255 ft)) and Epos (1,18 Thentes, betweesg of tuof 842.289 km2 (325.210 sq m
# ----
# iter 93000, loss: 0.515719
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 84 (3,3 ft)) and Epos (1,188 m (3,898 ft)), are situated in the n
# ----
# iter 94000, loss: 0.478366
# ----
#  hios island is crescent or kidney sherind id ntainon ar9 kr9  the ins rwpe sorth of the island. The center of the island. The center of the islande the length of the island. The two largest of these m
# ----
# iter 95000, loss: 0.454624
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its pon areaus ituated in the north of the island. The cend i) cethan area of 842.289 km2 (325.21
# ----
# iter 96000, loss: 0.430881
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to the mof 8r m (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq))
# ----
# iter 97000, loss: 0.407707
# ----
#  hios island is crescent or kidney shaped nort Pountains running the length of the island is divided between east and west by a range of smaller peaks, nor d kme mearrest of 842.289 km2 (325.210 sq mi)
# ----
# iter 98000, loss: 0.386025
# ----
#  hios island is crescents own west of these mountains, Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3,898 ft)), are situated in the north of the island. The center of the island. The two largest of
# ----
# iter 99000, loss: 0.911776
# ----
#  hios island is crescent and arid int and i ns peaks, knountainous or crescent of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and arid, with a ridge of smlatesthe of smaller peaks, known
# ----
# iter 100000, loss: 0.705258
# ----
#  hios island is crescent Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3,898 ft)), are kaned is peaks, known as Prto fountan a rang tor sma rior cedne nd id laned is anne kange ma island. The center
# ----
# iter 101000, loss: 0.503081
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its wide shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, coverin
# ----
# iter 102000, loss: 0.416604
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north tuof 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and arid, with a ridge of mountains runod 5 bd29 km (318 km2.289
# ----
# iter 103000, loss: 0.373825
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an aree islande celineon (1,297 m (4,255 ft)) and Epos (1,188 m (3,898 ft)),
# ----
# iter 104000, loss: 0.351493
# ----
#  hios island is crescent or.[2] The terrain is mountainin as Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3,898 ft)), aisthaentain an kid wees mounte nd Epo mauntains running the length of the isla
# ----
# iter 105000, loss: 0.336518
# ----
#  hios island is crert and west by a range of smaller peaks, known as Prto sounteateos (1,29 kmi) screas kpenter of the island. The center of the island is divided between east and west by a range of sm
# ----
# iter 106000, loss: 1.025620
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, kid is divided between east and west by a range of smaller peaks, known as Prto south
# ----
# iter 107000, loss: 0.644702
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an wid e of moung an areas kirin is mountains running the length of the isla
# ----
# iter 108000, loss: 0.489393
# ----
#  hios island is crescent or kidne non kselinte lrin  ange of smaller peatso mathi), o98 ft)), are situated in n cre situated in n kselin an area of 842.289 km2 (325.210 sq mi).[2] The the situated in t
# ----
# iter 109000, loss: 0.431816
# ----
#  hios island is crescent of 842.289 kmuden ndney sh,weong fr28 m bestd2.289 km2 (325.210 sq mi).[2] The terrain is mountainous and arid, with a ridge of mountains running the length of the island. The
# ----
# iter 110000, loss: 0.408035
# ----
#  hios island id the oun is mounteon (1,297 m (4,255 ft)) and Epos (1,188 m (3,898 ft)), are situated in the north of the island. The two largest of these mountains, Pelineon (1,297 m (4,255 ft)) and Ep
# ----
# iter 111000, loss: 0.787622
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainin lans sm
# ----
# iter 112000, loss: 0.542369
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) ra terrain is mountainous and arid, with a ridge of mountains running the length of the island is di
# ----
# iter 113000, loss: 0.442932
# ----
#  hios island is crescent Pelleng an patge of smaller peaks, known as Prto south, and between east and west by a range of smaller peaks, known as Prto south, and 29 km (18 mi) at its widest, covering an
# ----
# iter 114000, loss: 0.404851
# ----
#  hirs covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and arid, with a ridge of mountains running the length of the island. The center of the island. The center of the is
# ----
# iter 115000, loss: 0.395179
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) landne of the island is divided between east and west by a range of smaller peaks, known anoof km mo
# ----
# iter 116000, loss: 0.397071
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from nort and west by a range of smast by a range of smaller peaks, known as Prto soo kme) smlong from north to south, and 29 km (18 mi) at
# ----
# iter 117000, loss: 0.389244
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq km88 r84,29 km (18 mi) at its widest, cov
# ----
# iter 118000, loss: 0.922962
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] Then the island ia th a ridge of
# ----
# iter 119000, loss: 0.569721
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long frovi rid nor kidney shapth of the island. The two largest of these mountains, Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3,898 ft)),
# ----
# iter 120000, loss: 0.631757
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and ar
# ----
# iter 121000, loss: 0.469808
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 m Pelin e island is divided between east and west by a rangeh of 88 (18 mi) long fr2 kmey shaped north o
# ----
# iter 122000, loss: 0.753360
# ----
#  hios island Epos (1,188 m (3,898 ft)), are north of the island a por kid weringusthe of m nd, Pelis and Epos (1,188 m (3,898 ft)), are situated Pelineon (1,297 m th n asnd Epos (1,188 m (3,898 ft)), a
# ----
# iter 123000, loss: 0.595580
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and ar
# ----
# iter 124000, loss: 0.510797
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and ar
# ----
# iter 125000, loss: 0.566741
# ----
#  hios island is crescent or kidney shaped, 50 km (31, med, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terarid, Pele
# ----
# iter 126000, loss: 0.496872
# ----
#  hios is (3,8 ft) kteos (1,188 m (3,898 ft)), are situated in the north of the island. The two largest of these mountains, Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3,898 ft)), are slandney shap
# ----
# iter 127000, loss: 0.436981
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km288 ft)), ar97 8q f0 (4,255 ft)) and Epos (1,188 m (3,8
# ----
# iter 128000, loss: 0.441659
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and ar
# ----
# iter 129000, loss: 0.395250
# ----
#  hios island is crescent of 842.289 km2 (325.210 sq mi).[2] The terraid. by a range of smalor arios (1,297 m (4,255 ft)) and Epos (1,188 m (3,898 ft)), are situated in the north of the island. The cent
# ----
# iter 130000, loss: 0.458513
# ----
#  hios island is crescent or kidney shanountang two largest of these mountains, Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3,898 ft)), are situated in the north of the island. The center of the is
# ----
# iter 131000, loss: 0.410650
# ----
#  hios islatgand west by a range of smaller peaks, known as Prto south, and 2929 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain ir raid a kidney shaped, 50 km
# ----
# iter 132000, loss: 0.389152
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and ar
# ----
# iter 133000, loss: 0.384041
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering aivisllength om nong from north as kmente islate pon kselon 21in the north o
# ----
# iter 134000, loss: 0.383184
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north tuos km peaks, knountain the north of the island. The two largest of these mountains, Pelineon (1,297 m (4,255 ft)) and Eteateo1
# ----
# iter 135000, loss: 0.383656
# ----
#  hios island in kse situated inous and Epos (1,188 m (3,898 ft)), are situated in the north of the island. The two largest of these mountains, Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3,898 ft)
# ----
# iter 136000, loss: 0.579290
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and ar
# ----
# iter 137000, loss: 0.451402
# ----
#  hios island is crescent or kidney sh widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountain n ponlandnean. (3,898 ft)), are situated in the north of the island. The center
# ----
# iter 138000, loss: 0.692543
# ----
#  hios island is crescent or the noruasterrain is mountainous and arid, with a ridge of mountains running the length of the island is divided between east anea shaped, 50 km (31 mi) long from north to s
# ----
# iter 139000, loss: 0.493347
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an ares and 0 (3,8 fn) the north of the island. The two largest of these mou
# ----
# iter 140000, loss: 0.416234
# ----
#  hios island is crescent or kidney shaped, 50 km (31, me)ney s Pelenes Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3, P0 km nd id Enond 29 km (18 mi) at ith, lare ntains mom tuath erin is mounteon
# ----
# iter 141000, loss: 0.381715
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and ar
# ----
# iter 142000, loss: 0.366497
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and ar
# ----
# iter 143000, loss: 0.357335
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area and is noruateonth of the island is divided between east and west by
# ----
# iter 144000, loss: 0.350757
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, aid a smountainous,, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its
# ----
# iter 145000, loss: 0.345351
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and ar
# ----
# iter 146000, loss: 0.341717
# ----
#  hios island is crescent or kidney shaped, 50 km (3,898 ft)), are situated in the north of the island is divided between east ate nouth of the island. The center of the island. The two largest of they
# ----
# iter 147000, loss: 0.643569
# ----
#  hios island geanin ad 5 (31 29 ft)) and Epos (1,188 m (3,898 ft)), are scond Thes mountainous and arid, with a ridge of mountains running the length of the island. The center of the island. The center
# ----
# iter 148000, loss: 0.500778
# ----
#  hios ist aliner anges pof smalleras auntuate of smaller peaks, of nweasn nd Epos (1,188 m (3,898 ft)), are situated in the situated in n the north of the island. The center of the island. The center o
# ----
# iter 149000, loss: 0.387844
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) lengest of these mountains, Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3,898 ft)), are situate
# ----
# iter 150000, loss: 0.924058
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and arid, with a ridge of mountains running the, ,
# ----
# iter 151000, loss: 0.557660
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to argth a ridge of mountains running the length of the island. The center of the island is divided between east and west by a r
# ----
# iter 152000, loss: 0.419858
# ----
#  hios island is crescenth centho mountainous and arid, with a ridge of mountains running the length of the island. The center of the island is divided between east and west by a range of smaller peasta
# ----
# iter 153000, loss: 0.418591
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) at ingd Epos (1,188 m (3,898 ft)), are sord 50 km (3,898 ft)), are situated in the north of the island. The center of the island. The cend, 50 k
# ----
# iter 154000, loss: 0.362115
# ----
#  hios is (3,8h 5) km2 (325.210 sq mi).[2] The terrain is mountainous and arid, with a ridge of mountains running the length of the island is divided between east and west by a range of smaller peaks, k
# ----
# iter 155000, loss: 0.325265
# ----
#  hios island is crescent or kidney shaknd d wTheane, Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3,898 ft)), are situated in the north of the island is divided between ang largest of these mountai
# ----
# iter 156000, loss: 0.318451
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain ar at its widest, cov
# ----
# iter 157000, loss: 0.607557
# ----
#  hios island is crescent or kidney shaped, betwerid a tareand is (1,898 ft)), are situated in the north of the island is divided between east and west by a range of smaller peaks, known as Prto south,
# ----
# iter 158000, loss: 0.445719
# ----
#  hios island is cresceded 89th th a ridge of mountains running the length of the island is divided between the ing mof muntwi svousth aney of 89 mom the cent and wid1 mundest by a range of smaller peak
# ----
# iter 159000, loss: 0.388394
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an awea d3 842.28rsq f89 km (18 mi) at its widest, covering an area of 842.2
# ----
# iter 160000, loss: 0.519758
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to h, peaks, knof  of the island. The two largest of these mountains, Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3,898 ft)
# ----
# iter 161000, loss: 0.461470
# ----
#  hios island is crese of moustha divided between east and west by a range of smaller peaks, mathe noun an n the nor kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its wides
# ----
# iter 162000, loss: 0.400234
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and ar
# ----
# iter 163000, loss: 0.532131
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and ar
# ----
# iter 164000, loss: 0.411061
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and ar
# ----
# iter 165000, loss: 0.376394
# ----
#  hios island is cresom mountains running the length of the island. The center of the island. The center of the island is divided between east and west by a range of smaller peaks, known as Prais mounta
# ----
# iter 166000, loss: 0.665713
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and ar
# ----
# iter 167000, loss: 0.559644
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km fets of the island. The two largest of these mountains, Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3,8
# ----
# iter 168000, loss: 0.414537
# ----
#  hios island is creat ain. (31 mi) long from north to south, and 29 km (18 mi) at its widest, coverre situated in the nor kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its
# ----
# iter 169000, loss: 0.342357
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) lrid a kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[
# ----
# iter 170000, loss: 0.330279
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mith of m nderin  rains running the length of the island. The two largest of these mountains, Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3,898
# ----
# iter 171000, loss: 0.362251
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) lrid a sfod 29 km (18 mi) at its widest, covering an area of th aped, 50 km (31 mi) long from nos Prto sof 842.289 km (18 mi) at its widest, cov
# ----
# iter 172000, loss: 0.354535
# ----
#  hios island is crescenth the of smastoweange noresto snd,gtha Epethe) ans mountains running the length of the isth of the islate of smaller mof the island. The two largest of these Peountains running
# ----
# iter 173000, loss: 0.568207
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) aks, known asviown west of these mountains, Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3,898 f
# ----
# iter 174000, loss: 0.399402
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to , ka ge of smaller rowi, (3, 29 kmed (4,255 ft)) and Epos (1,188 m (3,898 ft)), are situated inin island is are slis mountain
# ----
# iter 175000, loss: 0.426877
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from nort ft)), from nort of th are situated in the north of the island. The two land werin  rainous, of the island is divided by a range o
# ----
# iter 176000, loss: 0.463242
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) lrid a kidney shaped, 50 km (31th the in as Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3,898 ft)), are sitha is d218 T), ft)), are situate
# ----
# iter 177000, loss: 0.411520
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (3250 km (31 mi) long from north to south, and 29 km
# ----
# iter 178000, loss: 0.331065
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) land ist and ra in nd Epo land. The center of the island. The two largest of these mountains, Peline
# ----
# iter 179000, loss: 0.282792
# ----
#  hios island is crescent cet rom d id kmend nous and ar knd wiwod Thes Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3,898 ft)), are situated in llent and werin n sland raed id i) an area of 842.289
# ----
# iter 180000, loss: 0.264764
# ----
#  hios is divided between east and west by a range of smaller peaks, known as Prto south, and 29 km (18 mi) at its wider om smat its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terra
# ----
# iter 181000, loss: 0.273063
# ----
#  hios island is nthe island is ans mounta n ast of smlong from nortart arir cent acre com of the island. The cent, with a ridney shaped, 50 km (3,898 ft)), are situate north of the islarg from nort f k
# ----
# iter 182000, loss: 1.324234
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and ar
# ----
# iter 183000, loss: 0.786432
# ----
#  hios island ir aid is divided betweesceatge cent ountains runn nor coverin  divided be kid east mountains running the length of the island. The two larges, with a smalneunede sndt by a range of smalle
# ----
# iter 184000, loss: 0.421889
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long fror m mountpet its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and arid, with a ridge of mounta
# ----
# iter 185000, loss: 0.272200
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and ar
# ----
# iter 186000, loss: 0.213892
# ----
#  hios iscedng of the island is divided between east and west by a range of smaller peaks, known as Prto soo kmenrs, are situated in the north of the island. The two largest of these mountains, Pelineon
# ----
# iter 187000, loss: 0.192951
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 2w knd vid ealledivided between east and west by a range of smaller peaks, known as Prais mountainous and arid, wi
# ----
# iter 188000, loss: 0.929543
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its worse mountains, betwid eat ith a ridge of Penor m (31t ith, an area of 842.289 km2 (325.210
# ----
# iter 189000, loss: 0.567019
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long fi)), from nd is mountainou (1,29 km2 (ed, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an a red, wine
# ----
# iter 190000, loss: 0.426594
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, kid istains, Pelinte largest of these mountains, Pelineon (1,297 m (4,255 ft)) and Ep
# ----
# iter 191000, loss: 0.374863
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, coveon the length of the islander ith arescand th are situated in the north of the is
# ----
# iter 192000, loss: 0.363170
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and ar
# ----
# iter 193000, loss: 0.535215
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at itslane pan area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and arid, with a r
# ----
# iter 194000, loss: 0.406975
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and ar
# ----
# iter 195000, loss: 0.362723
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and ar
# ----
# iter 196000, loss: 0.341707
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, crese wiunerains running the length of the island. The two largest of these mountains
# ----
# iter 197000, loss: 0.337887
# ----
#  hios isced, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 8421 t9it andne s, m nderest of these mountains, Pelineon (1,297 m (4,255 ft)) and Epos (1,188
# ----
# iter 198000, loss: 0.335591
# ----
# ...
# ----
# iter 487000, loss: 0.178085
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and ar
# ----
# iter 488000, loss: 0.404975
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long artpeat its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and arid, with, and 29 km (18 mi) at its
# ----
# iter 489000, loss: 0.545397
# ----
#  hios island is the north of the island is divided between east area tha d mor ats[ md, km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and arid
# ----
# iter 490000, loss: 0.429667
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to sorthe length of the island. The two largest of these mountains, Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3,898 ft)),
# ----
# iter 491000, loss: 0.424200
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and ar
# ----
# iter 492000, loss: 0.347539
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering am nang an nd 29 km (18 mi) at its widest, covering an area of 842.289 km2 (
# ----
# iter 493000, loss: 0.312947
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from to south, and 29 (325.210 sq mi).[2] The terrain is mountainous and arid, with a ridge of mountains runnor kidney shaped, 5 (4,255 ft)
# ----
# iter 494000, loss: 0.458835
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and ar
# ----
# iter 495000, loss: 0.348432
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and ar
# ----
# iter 496000, loss: 0.645766
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and ar
# ----
# iter 497000, loss: 0.484615
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km m (31 mi) loun ning the length of the island. The two largest of these sounedes mountains running the length
# ----
# iter 498000, loss: 0.691973
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and ar
# ----
# iter 499000, loss: 0.474379
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and ar
# ----
# iter 500000, loss: 0.389892
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and ar
# ----
# iter 501000, loss: 0.291453
# ----
#  hios island is crnd sherorg aus and 29 km (18 mi) at its widest, coveringes and is norurso kmand i sta kange of smalisthanist of the the norust by a range of smaller peaks, known as Prtoe long from no
# ----
# iter 502000, loss: 0.259110
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from to south, peange of smaller peaks, known as Prtoe lengd id, with, an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainou
# ----
# iter 503000, loss: 0.277511
# ----
#  hios island is crescent or kidney shaped, 50 km (3,898 ft)), are situated is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842
# ----
# iter 504000, loss: 0.286977
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, coverin slin ang two lenter owd is (enownthe length of the island. The two largest of
# ----
# iter 505000, loss: 0.457384
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and ar
# ----
# iter 506000, loss: 0.427620
# ----
#  hios island is crescent or kidney shaped, 50 km (3,898 ft)), are situated in the north of the island. The center of the island. The center of the island is divided between east and west by a range of
# ----
# iter 507000, loss: 0.368284
# ----
#  hios island is crescent and is of the islanglaney shaped, Pat by a range of smaller peaks, kange of smaller peaks8 ft)), are situated in the north of the island is divided between east ard  ange of sm
# ----
# iter 508000, loss: 0.315541
# ----
#  hios island island is (31 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terre then dn n sooust mountains running the length of the island. The center of the island is divi
# ----
# iter 509000, loss: 0.312362
# ----
#  hios island is crescent and is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mo
# ----
# iter 510000, loss: 0.393613
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The nor, an naed is crescent or k
# ----
# iter 511000, loss: 0.264365
# ----
#  hios island is crescent of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and arid, with a ridge of mountains running the length of the island. The two laridng an area of 842.289 km2 (325.
# ----
# iter 512000, loss: 0.219989
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is Pelineon (1,297 m
# ----
# iter 513000, loss: 0.546653
# ----
#  hios island is south centhe long from north to south, and 29 km (18 mi) atso ft orland is ange of smaller peaks, known as Prto sousthenos rarted iond lange or cres mof the two lengestwon ased (31 mi)
# ----
# iter 514000, loss: 0.397257
# ----
#  hios island is ftheast and west Pat cen divis divided between east and west by a range of smaller peaks, known as Prtoe long ardinone or crescent or kidge of Pelineon (1,297 m (4,255 ft)) and Epos (1,
# ----
# iter 515000, loss: 0.344503
# ----
#  hios island in the north of the island is divided between east and west by a.289 km2 (325.210 sq mi).[2] The terrain id.1, 1nthe of mountains runein the north of the island. The center of the island i
# ----
# iter 516000, loss: 0.323141
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from nort and wTh ea d is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its area tha divided betw
# ----
# iter 517000, loss: 0.297202
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) atso ft or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, c
# ----
# iter 518000, loss: 0.272352
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] Then nese mountains, Pelineon (1,
# ----
# iter 519000, loss: 0.260267
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an arainses and 29 km (18 mi) at its widest, covering an area of 842.289 km2
# ----
# iter 520000, loss: 0.250030
# ----
#  hios island is crescent or kidney  aneins sheast and west by a range of smaller peaks, known as Prtoeslat ne north of the island is divided between east and west by a range of smaller peaks, known as
# ----
# iter 521000, loss: 0.250868
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and ar
# ----
# iter 522000, loss: 0.257068
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and ar
# ----
# iter 523000, loss: 0.266302
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and ar
# ----
# iter 524000, loss: 0.287267
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its,ea by a range of smaller peaks, known as Prto.25.2q kt)) and Epos (1,188 m (3,898 ft)), are s
# ----
# iter 525000, loss: 0.297724
# ----
#  hios island is ftheast ft or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain in ane langest of t
# ----
# iter 526000, loss: 0.282594
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and ar
# ----
# iter 527000, loss: 0.816667
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south a ridge of mountains running the length of the island. Pe(1,898 ft)), are situated in the north of the island. The cent
# ----
# iter 528000, loss: 0.500029
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and ar
# ----
# iter 529000, loss: 0.845440
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and ar
# ----
# iter 530000, loss: 0.488121
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) lond. Tf npeand Epos (1,188 m (3,898 ft)), are situated in the north of the island is divided between east and west by a range of smaller peaks,
# ----
# iter 531000, loss: 0.346948
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from norg from no nd 29 km (18 mi) at ated pof 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of
# ----
# iter 532000, loss: 0.303387
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and ar
# ----
# iter 533000, loss: 0.330190
# ----
#  hios island is crescent or kidney shanor crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The ter
# ----
# iter 534000, loss: 0.323727
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) rand is ange of smaller peaks, known as Prtoe long from north to south, and 29 km (18 mi) at its wid
# ----
# iter 535000, loss: 0.312866
# ----
#  hios island is crescent or sooust or kidney shaped, with, and 29 km (18 mi) at inedest and ar9 kis alerist and isllength of the island. The two largest of these mountains, The cent.[2]298 m ndngest of
# ----
# iter 536000, loss: 0.552725
# ----
#  hios island is creruosland is (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and arid, with arois cre
# ----
# iter 537000, loss: 0.568164
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mid i) or crescent or kidney shaped, 50 k
# ----
# iter 538000, loss: 0.413330
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and ar
# ----
# iter 539000, loss: 0.340482
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and ar
# ----
# iter 540000, loss: 0.295176
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and ar
# ----
# iter 541000, loss: 0.256602
# ----
#  hios island is crescent or kidney shaped, 50 km (3,898 ft)), are situated in the north of the island. The two largest of these mountains, Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3,898 ft)), a
# ----
# iter 542000, loss: 0.228674
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and ar
# ----
# iter 543000, loss: 0.210786
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long fouthaterto sf ndee mountains, Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3,898 ft)), are situated in the north of the island. The ce
# ----
# iter 544000, loss: 0.199453
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terre the north of the island
# ----
# iter 545000, loss: 0.191928
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and ar
# ----
# iter 546000, loss: 0.186447
# ----
#  hios is divided between east and west by a range of smaller peaks, known as Prtoe shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.
# ----
# iter 547000, loss: 0.181870
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and ar
# ----
# iter 548000, loss: 0.177444
# ----
#  hios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and ar
# ----
# iter 549000, loss: 0.172633
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-33c59adb5ec0> in <module>()
#      19
#      20   # forward seq_length characters through the net and fetch gradient
# ---> 21   loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
#      22   smooth_loss = smooth_loss * 0.999 + loss * 0.001
#      23   if n % 1000 == 0: print('iter %d, loss: %f' % (n, smooth_loss)) # print progress
#
# <ipython-input-8-372860b6a6b9> in lossFun(inputs, targets, hprev)
#      31     dWxh += np.dot(dhraw, xs[t].T)
#      32     dWhh += np.dot(dhraw, hs[t-1].T)
# ---> 33     dhnext = np.dot(Whh.T, dhraw)
#      34   for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
#      35     np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:
